# %%
# import libraries here; add more as necessary
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
pd.options.display.max_rows = 4000

# magic word for producing visualizations in notebook
# %matplotlib inline

# %%
# Load in the general 2018 dataset.
survey_2018 = pd.read_csv("survey_results_public_2018.csv", dtype=str)

# %%
print(survey_2018.head())
# Out:
#   Respondent Hobby OpenSource         Country         Student  \
# 0          1   Yes         No           Kenya              No
# 1          3   Yes        Yes  United Kingdom              No
# 2          4   Yes        Yes   United States              No
# 3          5    No         No   United States              No
# 4          7   Yes         No    South Africa  Yes, part-time
#
#            Employment                                    FormalEducation  \
# 0  Employed part-time           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 1  Employed full-time           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 2  Employed full-time                                   Associate degree
# 3  Employed full-time           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 4  Employed full-time  Some college/university study without earning ...
#
#                                       UndergradMajor  \
# 0                          Mathematics or statistics
# 1  A natural science (ex. biology, chemistry, phy...
# 2  Computer science, computer engineering, or sof...
# 3  Computer science, computer engineering, or sof...
# 4  Computer science, computer engineering, or sof...
#
#                 CompanySize  \
# 0        20 to 99 employees
# 1  10,000 or more employees
# 2        20 to 99 employees
# 3      100 to 499 employees
# 4  10,000 or more employees
#
#                                              DevType      ...        \
# 0                               Full-stack developer      ...
# 1  Database administrator;DevOps specialist;Full-...      ...
# 2           Engineering manager;Full-stack developer      ...
# 3                               Full-stack developer      ...
# 4  Data or business analyst;Desktop or enterprise...      ...
#
#                      Exercise Gender         SexualOrientation  \
# 0        3 - 4 times per week   Male  Straight or heterosexual
# 1   Daily or almost every day   Male  Straight or heterosexual
# 2                         NaN    NaN                       NaN
# 3  I don't typically exercise   Male  Straight or heterosexual
# 4        3 - 4 times per week   Male  Straight or heterosexual
#
#                                     EducationParents  \
# 0           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 1           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 2                                                NaN
# 3  Some college/university study without earning ...
# 4  Some college/university study without earning ...
#
#                   RaceEthnicity                Age Dependents MilitaryUS  \
# 0   Black or of African descent  25 - 34 years old        Yes        NaN
# 1  White or of European descent  35 - 44 years old        Yes        NaN
# 2                           NaN                NaN        NaN        NaN
# 3  White or of European descent  35 - 44 years old         No         No
# 4  White or of European descent  18 - 24 years old        Yes        NaN
#
#                           SurveyTooLong     SurveyEasy
# 0  The survey was an appropriate length      Very easy
# 1  The survey was an appropriate length  Somewhat easy
# 2                                   NaN            NaN
# 3  The survey was an appropriate length  Somewhat easy
# 4  The survey was an appropriate length  Somewhat easy
#
# [5 rows x 129 columns]

# %%
print(survey_2018.shape)
survey_2018.describe()
# Out:
# (98855, 129)
#        Respondent  Hobby OpenSource        Country Student  \
# count       98855  98855      98855          98443   94901
# unique      98855      2          2            183       3
# top         52434    Yes         No  United States      No
# freq            1  79897      55769          20309   70399
#
#                 Employment                           FormalEducation  \
# count                95321                                     94703
# unique                   6                                         9
# top     Employed full-time  Bachelor’s degree (BA, BS, B.Eng., etc.)
# freq                 70495                                     43659
#
#                                            UndergradMajor         CompanySize  \
# count                                               79036               71531
# unique                                                 12                   8
# top     Computer science, computer engineering, or sof...  20 to 99 employees
# freq                                                50336               16996
#
#                    DevType      ...                          Exercise Gender  \
# count                92098      ...                             72108  64469
# unique                9568      ...                                 4     15
# top     Back-end developer      ...        I don't typically exercise   Male
# freq                  6417      ...                             26995  59458
#
#                SexualOrientation                          EducationParents  \
# count                      59765                                     61813
# unique                        14                                         9
# top     Straight or heterosexual  Bachelor’s degree (BA, BS, B.Eng., etc.)
# freq                       55013                                     18090
#
#                        RaceEthnicity                Age Dependents MilitaryUS  \
# count                          57473              64574      62596      15781
# unique                            71                  7          2          2
# top     White or of European descent  25 - 34 years old         No         No
# freq                           40541              31759      44478      15043
#
#                                SurveyTooLong     SurveyEasy
# count                                  65941          65879
# unique                                     3              5
# top     The survey was an appropriate length  Somewhat easy
# freq                                   33257          24434
#
# [4 rows x 129 columns]

# %%
# Perform an assessment of how much missing data there is in each column of the
# dataset.
def count_outliers(dataset):
    # output percentage of values that are missing
    print(100 * dataset.isnull().sum() / dataset.shape[0])

# %%
count_outliers(survey_2018)
# Out:
# Respondent                      0.000000
# Hobby                           0.000000
# OpenSource                      0.000000
# Country                         0.416772
# Student                         3.999798
# Employment                      3.574933
# FormalEducation                 4.200091
# UndergradMajor                 20.048556
# CompanySize                    27.640484
# DevType                         6.835264
# YearsCoding                     5.078145
# YearsCodingProf                21.194679
# JobSatisfaction                29.921602
# CareerSatisfaction             22.609883
# HopeFiveYears                  23.404987
# JobSearchStatus                19.591321
# LastNewJob                     20.197259
# AssessJob1                     32.239138
# AssessJob2                     32.239138
# AssessJob3                     32.239138
# AssessJob4                     32.239138
# AssessJob5                     32.239138
# AssessJob6                     32.239138
# AssessJob7                     32.239138
# AssessJob8                     32.239138
# AssessJob9                     32.239138
# AssessJob10                    32.239138
# AssessBenefits1                34.330079
# AssessBenefits2                34.330079
# AssessBenefits3                34.330079
# AssessBenefits4                34.330079
# AssessBenefits5                34.330079
# AssessBenefits6                34.330079
# AssessBenefits7                34.330079
# AssessBenefits8                34.330079
# AssessBenefits9                34.330079
# AssessBenefits10               34.330079
# AssessBenefits11               34.331091
# JobContactPriorities1          50.729857
# JobContactPriorities2          50.729857
# JobContactPriorities3          50.729857
# JobContactPriorities4          50.729857
# JobContactPriorities5          50.729857
# JobEmailPriorities1            53.251732
# JobEmailPriorities2            53.251732
# JobEmailPriorities3            53.251732
# JobEmailPriorities4            53.251732
# JobEmailPriorities5            53.251732
# JobEmailPriorities6            53.251732
# JobEmailPriorities7            53.251732
# UpdateCV                       33.701887
# Currency                       37.273785
# Salary                         48.836174
# SalaryType                     48.338476
# ConvertedSalary                51.745486
# CurrencySymbol                 40.670679
# CommunicationTools             42.370138
# TimeFullyProductive            47.527186
# EducationTypes                 31.252845
# SelfTaughtTypes                41.981690
# TimeAfterBootcamp              93.270952
# HackathonReasons               74.011431
# AgreeDisagree1                 30.992868
# AgreeDisagree2                 30.862374
# AgreeDisagree3                 30.844166
# LanguageWorkedWith             20.758687
# LanguageDesireNextYear         25.907643
# DatabaseWorkedWith             32.962420
# DatabaseDesireNextYear         41.836022
# PlatformWorkedWith             33.236559
# PlatformDesireNextYear         37.936371
# FrameworkWorkedWith            47.782105
# FrameworkDesireNextYear        44.142431
# IDE                            23.728694
# OperatingSystem                22.938648
# NumberMonitors                 22.717111
# Methodology                    40.335845
# VersionControl                 24.841434
# CheckInCode                    26.806939
# AdBlocker                      23.064084
# AdBlockerDisable               44.466137
# AdBlockerReasons               61.817814
# AdsAgreeDisagree1              24.652268
# AdsAgreeDisagree2              24.725102
# AdsAgreeDisagree3              24.724091
# AdsActions                     39.796672
# AdsPriorities1                 38.820495
# AdsPriorities2                 38.820495
# AdsPriorities3                 38.820495
# AdsPriorities4                 38.820495
# AdsPriorities5                 38.820495
# AdsPriorities6                 38.820495
# AdsPriorities7                 38.820495
# AIDangerous                    36.153963
# AIInteresting                  33.875879
# AIResponsible                  33.687724
# AIFuture                       29.464367
# EthicsChoice                   28.398159
# EthicsReport                   28.758282
# EthicsResponsible              34.712458
# EthicalImplications            29.888220
# StackOverflowRecommend         22.625057
# StackOverflowVisit             22.299327
# StackOverflowHasAccount        22.319559
# StackOverflowParticipate       33.498558
# StackOverflowJobs              23.830863
# StackOverflowDevStory          33.562288
# StackOverflowJobsRecommend     61.239189
# StackOverflowConsiderMember    23.112640
# HypotheticalTools1             29.120429
# HypotheticalTools2             29.136614
# HypotheticalTools3             29.190228
# HypotheticalTools4             29.203379
# HypotheticalTools5             29.143695
# WakeTime                       27.018360
# HoursComputer                  27.031511
# HoursOutside                   27.141773
# SkipMeals                      27.220677
# ErgonomicDevices               65.547519
# Exercise                       27.056800
# Gender                         34.784280
# SexualOrientation              39.542765
# EducationParents               37.471043
# RaceEthnicity                  41.861312
# Age                            34.678064
# Dependents                     36.678974
# MilitaryUS                     84.036215
# SurveyTooLong                  33.295230
# SurveyEasy                     33.357949
# dtype: float64

# %% [markdown]
# Based off of the graph above, there are roughly 6 outlier columns that I will be removing as they stick out over the rest of the dataset.
